# %%
 # To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %% [markdown]
# # VacationPy
# ----
# 
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# %%
# Import API key
from api_keys import g_key
gmaps.configure(api_key = g_key)

# %% [markdown]
# # Store Part I results into DataFrame
# ## Load the csv exported in Part I to a DataFrame

# %%
weather_df = pd.read_csv("weather_data.csv")
weather_df.head()
# Out:
#    City ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0      butaritari          75      KI  1586114686        78   3.07
# 1        1     bodden town          20      KY  1586114804        66  19.28
# 2        2  port elizabeth          60      ZA  1586114805        82 -33.92
# 3        3           lagoa         100      PT  1586114805        83  39.05
# 4        4       saryagash          90      KZ  1586114805       100  41.45
#
#       Lng  Max Temp  Wind Speed
# 0  172.79    301.24        6.06
# 1  -81.25    304.15        4.10
# 2   25.57    291.15        6.70
# 3  -27.98    286.90        7.39
# 4   69.17    285.15        1.00

# %%
# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.
# %%

# %%
gmaps.configure(api_key = g_key)

vaca_spots = weather_df[["Lat", "Lng"]]

figure = gmaps.figure()

hm_layer = gmaps.heatmap_layer(vaca_spots, weights=weather_df['Humidity'],
                                   dissipating=False, max_intensity=5,
                                   point_radius=1)
figure.add_layer(hm_layer)
figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.
# %%

# %%
#Create new data frame
getting_picky = pd.DataFrame(weather_df, columns=['City', 'Max Temp', 'Cloudiness', 'Wind Speed', 'Humidity', 'Lat', 'Lng','Country'])

#Convert temperature values from Kelvin to Farenheit
getting_picky['Max Temp'] = (getting_picky['Max Temp'] - 241.15) * (9/5)

#Convert Cloudiness, Humidity, and Wind Speed to numerics
getting_picky['Cloudiness'] = pd.to_numeric(getting_picky['Cloudiness'], downcast = 'float')
getting_picky['Wind Speed'] = pd.to_numeric(getting_picky['Wind Speed'], downcast = 'float')
getting_picky['Humidity'] = pd.to_numeric(getting_picky['Humidity'], downcast = 'float')
# %%

# %%
#Weather conditions:
    #Max temp = between 70-85
    #Cloudiness = <30
    #Windspeed >= 10%
    
not_too_hot = getting_picky[(getting_picky['Max Temp'] <= 85) & (getting_picky['Max Temp'] > 70)]
few_clouds = not_too_hot[not_too_hot['Cloudiness'] < 30]
gentle_breeze = few_clouds[few_clouds['Wind Speed'] < 10 ]

gentle_breeze
# Out:
#                City  Max Temp  Cloudiness  Wind Speed  Humidity    Lat  \
# 23         zharkent    84.888        28.0        1.90      30.0  44.16
# 59          kiskore    81.594         0.0        1.00      46.0  47.50
# 76        jamestown    75.600        20.0        4.60      70.0  42.10
# 98         adelaide    81.594        20.0        3.08      93.0 -34.93
# 116   alice springs    77.400        21.0        4.31      71.0 -23.70
# 127      port hardy    70.200        20.0        3.60      65.0  50.70
# 134   victor harbor    81.000        20.0        2.48      93.0 -35.57
# 179   mechetinskaya    71.064         0.0        3.37      53.0  46.77
# 189        glendive    77.598         1.0        7.20      45.0  47.11
# 213         waipawa    79.596         5.0        3.10      87.0 -41.41
# 262          trojan    73.602         0.0        2.27      45.0  53.79
# 280  great yarmouth    82.800         0.0        4.60      54.0  52.61
# 302        luderitz    84.600        12.0        3.60      87.0 -26.65
# 321      novyy svit    71.676         0.0        4.89      49.0  47.81
# 335          alpena    77.598         1.0        3.10      19.0  45.06
# 395       kathmandu    82.800        20.0        1.50      67.0  27.72
# 406        narrabri    78.606         0.0        3.10      87.0 -30.32
# 413      north bend    83.592         1.0        4.10      76.0  43.41
# 423            dali    73.368         0.0        1.76      25.0  25.70
# 432           ginda    76.446        18.0        2.78      27.0  30.69
# 441          alvand    70.146         0.0        0.79      38.0  36.32
# 446           ukiah    80.604        20.0        4.10      57.0  39.15
# 452         chifeng    70.614         0.0        1.76      38.0  42.27
# 497     san lawrenz    83.592         1.0        6.70      71.0  36.06
# 503         aubenas    82.800         0.0        1.50      44.0  44.62
#
#         Lng Country
# 23    80.00      KZ
# 59    20.50      HU
# 76   -79.24      US
# 98   138.60      AU
# 116  133.88      AU
# 127 -127.42      CA
# 134  138.62      AU
# 179   40.46      RU
# 189 -104.71      US
# 213  175.52      NZ
# 262   20.24      PL
# 280    1.73      GB
# 302   15.16     NaN
# 321   38.02      UA
# 335  -83.43      US
# 395   85.32      NP
# 406  149.78      AU
# 413 -124.22      US
# 423  100.18      CN
# 432   78.49      IN
# 441   49.17      IR
# 446 -123.21      US
# 452  118.96      CN
# 497   14.20      MT
# 503    4.39      FR

# %%
# %% [markdown]
# ### Hotel Map
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.
# %%

# %%
#Store new data as hotel_df
hotel_df = gentle_breeze

#Add a "Hotel Name" column
hotel_df["Hotel Name"] = ""
hotel_df["Lat"] = hotel_df["Lat"].astype(str)
hotel_df["Lng"] = hotel_df["Lng"].astype(str)

hotel_df["Location"] = hotel_df['Lat'].str.cat(hotel_df['Lng'],sep=",")
hotel_df


# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
api_key = "AIzaSyADJRwMX0OjYXkIO9Wau5M1YOW44OLxpls"
Location = hotel_df["Location"]

parameters = {
    "radius":5000,
    "types":"lodging",
    "key":api_key
}

for i, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    parameters["location"] = f"{lat},{lng}"
    name = requests.get(base_url, params=parameters).json()
    try:
        print(name["results"][0]["name"])
        hotel_df.loc[i, "Hotel Name"] = name["results"][0]["name"]
    except:
        print("error")
        pass
hotel_df


# %%
# Out:
# гостиница Satti
# All-Inn Köre
# Hampton Inn & Suites Jamestown
# The Chancellor on Currie
# Desert Palms Alice Springs
# Airport Inn
# Apollon Motor Inn
# Stoyanka, Shinomontazh, Dush
# Super 8 by Wyndham Glendive
# Tora Coastal Walk
# Warmia Resort
# Comfort Hotel Great Yarmouth
# LÜDERITZ NEST HOTEL
# Энергетик
# Big Bear Lodge
# Hotel Shanker Kathmandu
# Crossroads Hotel
# Red Lion Hotel Coos Bay
# Dali Travelling With Hostel
# Bherav Hotel Manpur
# error
# Hampton Inn Ukiah
# Junyu Tiancheng Hotel
# San Andrea Hotel
# ibis Aubenas
#                City  Max Temp  Cloudiness  Wind Speed  Humidity     Lat  \
# 23         zharkent    84.888        28.0        1.90      30.0   44.16
# 59          kiskore    81.594         0.0        1.00      46.0    47.5
# 76        jamestown    75.600        20.0        4.60      70.0    42.1
# 98         adelaide    81.594        20.0        3.08      93.0  -34.93
# 116   alice springs    77.400        21.0        4.31      71.0   -23.7
# 127      port hardy    70.200        20.0        3.60      65.0    50.7
# 134   victor harbor    81.000        20.0        2.48      93.0  -35.57
# 179   mechetinskaya    71.064         0.0        3.37      53.0   46.77
# 189        glendive    77.598         1.0        7.20      45.0   47.11
# 213         waipawa    79.596         5.0        3.10      87.0  -41.41
# 262          trojan    73.602         0.0        2.27      45.0   53.79
# 280  great yarmouth    82.800         0.0        4.60      54.0   52.61
# 302        luderitz    84.600        12.0        3.60      87.0  -26.65
# 321      novyy svit    71.676         0.0        4.89      49.0   47.81
# 335          alpena    77.598         1.0        3.10      19.0   45.06
# 395       kathmandu    82.800        20.0        1.50      67.0   27.72
# 406        narrabri    78.606         0.0        3.10      87.0  -30.32
# 413      north bend    83.592         1.0        4.10      76.0   43.41
# 423            dali    73.368         0.0        1.76      25.0    25.7
# 432           ginda    76.446        18.0        2.78      27.0   30.69
# 441          alvand    70.146         0.0        0.79      38.0   36.32
# 446           ukiah    80.604        20.0        4.10      57.0   39.15
# 452         chifeng    70.614         0.0        1.76      38.0   42.27
# 497     san lawrenz    83.592         1.0        6.70      71.0   36.06
# 503         aubenas    82.800         0.0        1.50      44.0   44.62
#
#          Lng Country                      Hotel Name       Location
# 23      80.0      KZ                 гостиница Satti     44.16,80.0
# 59      20.5      HU                    All-Inn Köre      47.5,20.5
# 76    -79.24      US  Hampton Inn & Suites Jamestown    42.1,-79.24
# 98     138.6      AU        The Chancellor on Currie   -34.93,138.6
# 116   133.88      AU      Desert Palms Alice Springs   -23.7,133.88
# 127  -127.42      CA                     Airport Inn   50.7,-127.42
# 134   138.62      AU               Apollon Motor Inn  -35.57,138.62
# 179    40.46      RU    Stoyanka, Shinomontazh, Dush    46.77,40.46
# 189  -104.71      US     Super 8 by Wyndham Glendive  47.11,-104.71
# 213   175.52      NZ               Tora Coastal Walk  -41.41,175.52
# 262    20.24      PL                   Warmia Resort    53.79,20.24
# 280     1.73      GB    Comfort Hotel Great Yarmouth     52.61,1.73
# 302    15.16     NaN             LÜDERITZ NEST HOTEL   -26.65,15.16
# 321    38.02      UA                       Энергетик    47.81,38.02
# 335   -83.43      US                  Big Bear Lodge   45.06,-83.43
# 395    85.32      NP         Hotel Shanker Kathmandu    27.72,85.32
# 406   149.78      AU                Crossroads Hotel  -30.32,149.78
# 413  -124.22      US         Red Lion Hotel Coos Bay  43.41,-124.22
# 423   100.18      CN     Dali Travelling With Hostel    25.7,100.18
# 432    78.49      IN             Bherav Hotel Manpur    30.69,78.49
# 441    49.17      IR                                    36.32,49.17
# 446  -123.21      US               Hampton Inn Ukiah  39.15,-123.21
# 452   118.96      CN           Junyu Tiancheng Hotel   42.27,118.96
# 497     14.2      MT                San Andrea Hotel     36.06,14.2
# 503     4.39      FR                    ibis Aubenas     44.62,4.39

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]


# %%
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2e79f1cb3048> in <module>
#      16
#      17 # %%
# ---> 18 marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
#      19 fig.add_layer(marker_layer)
#      20 fig
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
